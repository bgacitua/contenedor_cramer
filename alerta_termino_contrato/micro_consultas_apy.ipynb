# %% [markdown]
# Archivo de micro consultas API para no sobreescribir la BD

# %%
import requests
import os
from dotenv import load_dotenv
import pandas as pd
import pymysql
import time

load_dotenv()
# Out:
# True

# %%
# Configuración API
API_BASE_URL = "https://cramer.buk.cl/api/v1/chile/"
API_ENDPOINTS = {
    "licences": f"{API_BASE_URL}employees/absences/licences",
    "absences": f"{API_BASE_URL}employees/absences/absences",
    "permissions": f"{API_BASE_URL}employees/absences/permissions"
}
TOKEN = os.getenv("BUK_AUTH_TOKEN")

# Configuración BD
DB_HOST = os.getenv("IP") #REEMPLAZAR HOST SI ES DISTINTO
DB_USER = "rrhh_master" #REEMPLAZAR USUARIO 
DB_PASSWORD = os.getenv("clave_sql") #REEMPLAZAR CONTRASEÑA 
DB_NAME = "rrhh_app" #REEMPLAZAR NOMBRE DE BASE DE DATOS CREADA

# Imprimir las variables de entorno
print(f"TOKEN: {os.getenv('BUK_AUTH_TOKEN')}")
print(f"SQL: {os.getenv('clave_sql')}")
print(f"IP: {os.getenv('IP')}")
# Out:
# TOKEN: Xegy8dVsa1H8SFfojJcwYtDL
# SQL: _Cramer2025_
# IP: 10.254.32.110

# %%
# --- Configuración de Filtro por Rango de Fechas (Opcional) ---

# Cambia a True para activar el filtro por fechas. Si es False, usará el log incremental normal.
FILTRAR_POR_FECHAS = True

# Define el rango de fechas si FILTRAR_POR_FECHAS es True. Formato: "YYYY-MM-DD"
# La API de BUK filtra por la fecha de inicio de la incidencia.
FECHA_INICIO = "2025-09-01"
FECHA_FIN = "2025-09-08"

if FILTRAR_POR_FECHAS:
    print(f"🗓️ FILTRO POR FECHAS ACTIVADO: Se extraerán datos entre {FECHA_INICIO} y {FECHA_FIN}.")
else:
    print("⚙️ Usando modo de carga incremental normal (basado en el último ID del log).")
# Out:
# 🗓️ FILTRO POR FECHAS ACTIVADO: Se extraerán datos entre 2025-09-01 y 2025-09-08.

# %%
from db_utils import (obtener_datos_paginados, crear_e_insertar_tabla_actualiza, 
                    conectar_mysql, obtener_ultima_carga, actualizar_log_carga, 
                    construir_url_incremental)

# 1. Conectar a la base de datos
conexion, cursor = conectar_mysql(DB_HOST, DB_USER, DB_PASSWORD, DB_NAME)

# 2. Definir los endpoints que se van a procesar
endpoints_a_procesar = ["absences", "licences", "permissions"]

print("🚀 FASE 1: Actualizando tablas individuales...")

# 3. Iterar sobre cada endpoint para extraer y cargar sus datos
for endpoint in endpoints_a_procesar:
    print(f"\n🔄 --- Procesando Endpoint: '{endpoint}' ---")
    
    # --- PASO CLAVE: Asegurar que la tabla tiene una PRIMARY KEY en 'id' ---
    # Esto es fundamental para prevenir duplicados.
    try:
        print(f"🔑 Verificando PRIMARY KEY en la tabla '{endpoint}'...")
        # Este comando añade la clave primaria solo si no existe. Es seguro ejecutarlo siempre.
        cursor.execute(f"ALTER TABLE {endpoint} ADD PRIMARY KEY (id);")
        conexion.commit()
        print(f"✅ PRIMARY KEY asegurada en la tabla '{endpoint}'.")
    except Exception as e:
        # Si la clave ya existe, MySQL dará un error. Lo capturamos y confirmamos que todo está bien.
        if "Multiple primary key defined" in str(e):
            print(f"✅ La PRIMARY KEY ya existe en la tabla '{endpoint}'.")
        else:
            print(f"⚠️  No se pudo establecer la PRIMARY KEY: {e}")

    # Determinar la URL de la API a consultar
    url_endpoint = ""
    if FILTRAR_POR_FECHAS:
        base_url_endpoint = f"{API_BASE_URL}employees/absences/{endpoint}"
        url_endpoint = f"{base_url_endpoint}?start_date_after={FECHA_INICIO}&start_date_before={FECHA_FIN}"
        print(f"🗓️  Modo: Filtro por fechas. URL: {url_endpoint}")
    else:
        ultima_carga = obtener_ultima_carga(cursor, endpoint)
        url_endpoint = construir_url_incremental(API_BASE_URL, endpoint, ultima_carga)
        print(f"⚙️  Modo: Carga incremental. URL: {url_endpoint}")
    
    # Extraer los datos desde la API
    print("📡 Extrayendo datos...")
    datos_nuevos = obtener_datos_paginados(url_endpoint, TOKEN)
    
    if datos_nuevos:
        print(f"📊 {len(datos_nuevos)} registros encontrados. Actualizando tabla '{endpoint}' en MySQL...")
        crear_e_insertar_tabla_actualiza(cursor, conexion, endpoint, datos_nuevos)
        
        if not FILTRAR_POR_FECHAS:
            actualizar_log_carga(cursor, conexion, endpoint, datos_nuevos)
            print("📝 Log de carga incremental actualizado.")
    else:
        print(f"✅ No se encontraron registros nuevos para '{endpoint}'.")

print("\n🎉 FASE 1 COMPLETADA: Tablas individuales actualizadas.")
# Out:
# 🚀 Conectando a MySQL...
# ✅ Conectado a MySQL y usando la base: rrhh_app
# 🚀 FASE 1: Actualizando tablas individuales...
#
# 🔄 --- Procesando Endpoint: 'absences' ---
# 🔑 Verificando PRIMARY KEY en la tabla 'absences'...
# ⚠️  No se pudo establecer la PRIMARY KEY: (1062, "Duplicate entry '85714' for key 'absences.PRIMARY'")
# 🗓️  Modo: Filtro por fechas. URL: https://cramer.buk.cl/api/v1/chile/employees/absences/absences?start_date_after=2025-09-01&start_date_before=2025-09-08
# 📡 Extrayendo datos...
#
# 🚀 Comenzando la obtención de datos desde: https://cramer.buk.cl/api/v1/chile/employees/absences/absences?start_date_after=2025-09-01&start_date_before=2025-09-08
# 📄 Obteniendo página 1...
# ✅ Página 1: 25 datos obtenidos
# 📊 Total acumulado: 25 datos
# 📈 Páginas restantes: 24
# ✅ Página 1: 25 datos obtenidos
# 📊 Total acumulado: 25 datos
# 📈 Páginas restantes: 24
# 📄 Obteniendo página 2...
# 📄 Obteniendo página 2...
# ✅ Página 2: 25 datos obtenidos
# 📊 Total acumulado: 50 datos
# 📈 Páginas restantes: 23
# ✅ Página 2: 25 datos obtenidos
# 📊 Total acumulado: 50 datos
# 📈 Páginas restantes: 23
# 📄 Obteniendo página 3...
# 📄 Obteniendo página 3...
# ✅ Página 3: 25 datos obtenidos
# 📊 Total acumulado: 75 datos
# 📈 Páginas restantes: 22
# ✅ Página 3: 25 datos obtenidos
# 📊 Total acumulado: 75 datos
# 📈 Páginas restantes: 22
# 📄 Obteniendo página 4...
# 📄 Obteniendo página 4...
# ✅ Página 4: 25 datos obtenidos
# 📊 Total acumulado: 100 datos
# 📈 Páginas restantes: 21
# ✅ Página 4: 25 datos obtenidos
# 📊 Total acumulado: 100 datos
# 📈 Páginas restantes: 21
# 📄 Obteniendo página 5...
# 📄 Obteniendo página 5...
# ✅ Página 16: 25 datos obtenidos
# 📊 Total acumulado: 400 datos
# 📈 Páginas restantes: 9
# ✅ Página 16: 25 datos obtenidos
# 📊 Total acumulado: 400 datos
# 📈 Páginas restantes: 9
# 📄 Obteniendo página 17...
# 📄 Obteniendo página 17...
# ✅ Página 17: 25 datos obtenidos
# 📊 Total acumulado: 425 datos
# 📈 Páginas restantes: 8
# ✅ Página 17: 25 datos obtenidos
# 📊 Total acumulado: 425 datos
# 📈 Páginas restantes: 8
# 📄 Obteniendo página 18...
# 📄 Obteniendo página 18...
# ✅ Página 18: 25 datos obtenidos
# 📊 Total acumulado: 450 datos
# 📈 Páginas restantes: 7
# ✅ Página 18: 25 datos obtenidos
# 📊 Total acumulado: 450 datos
# 📈 Páginas restantes: 7
# 📄 Obteniendo página 19...
# 📄 Obteniendo página 19...
# ✅ Página 19: 25 datos obtenidos
# 📊 Total acumulado: 475 datos
# 📈 Páginas restantes: 6
# ✅ Página 19: 25 datos obtenidos
# 📊 Total acumulado: 475 datos
# 📈 Páginas restantes: 6
# 📄 Obteniendo página 20...
# 📄 Obteniendo página 20...
# ✅ Página 20: 25 datos obtenidos
# 📊 Total acumulado: 500 datos
# 📈 Páginas restantes: 5
# ✅ Página 20: 25 datos obtenidos
# 📊 Total acumulado: 500 datos
# 📈 Páginas restantes: 5
# 📄 Obteniendo página 21...
# 📄 Obteniendo página 21...
# ✅ Página 21: 25 datos obtenidos
# 📊 Total acumulado: 525 datos
# 📈 Páginas restantes: 4
# ✅ Página 21: 25 datos obtenidos
# 📊 Total acumulado: 525 datos
# 📈 Páginas restantes: 4
# 📄 Obteniendo página 22...
# 📄 Obteniendo página 22...
# ✅ Página 22: 25 datos obtenidos
# 📊 Total acumulado: 550 datos
# 📈 Páginas restantes: 3
# ✅ Página 22: 25 datos obtenidos
# 📊 Total acumulado: 550 datos
# 📈 Páginas restantes: 3
# 📄 Obteniendo página 23...
# 📄 Obteniendo página 23...
# ✅ Página 23: 25 datos obtenidos
# 📊 Total acumulado: 575 datos
# 📈 Páginas restantes: 2
# ✅ Página 23: 25 datos obtenidos
# 📊 Total acumulado: 575 datos
# 📈 Páginas restantes: 2
# 📄 Obteniendo página 24...
# 📄 Obteniendo página 24...
# ✅ Página 24: 25 datos obtenidos
# 📊 Total acumulado: 600 datos
# 📈 Páginas restantes: 1
# ✅ Página 24: 25 datos obtenidos
# 📊 Total acumulado: 600 datos
# 📈 Páginas restantes: 1
# 📄 Obteniendo página 25...
# 📄 Obteniendo página 25...
# ✅ Página 25: 23 datos obtenidos
# 📊 Total acumulado: 623 datos
# 📈 Páginas restantes: 0
# ✅ Página 25: 23 datos obtenidos
# 📊 Total acumulado: 623 datos
# 📈 Páginas restantes: 0
# 🎉 ¡Paginación completada! Total de datos obtenidos: 623
# 📊 623 registros encontrados. Actualizando tabla 'absences' en MySQL...
# 🚀 Insertando o actualizando registros en la tabla 'absences'...
# ✅ 623 registros insertados o actualizados en 'absences'.
#
# 🔄 --- Procesando Endpoint: 'licences' ---
# 🔑 Verificando PRIMARY KEY en la tabla 'licences'...
# 🎉 ¡Paginación completada! Total de datos obtenidos: 623
# 📊 623 registros encontrados. Actualizando tabla 'absences' en MySQL...
# 🚀 Insertando o actualizando registros en la tabla 'absences'...
# ✅ 623 registros insertados o actualizados en 'absences'.
#
# 🔄 --- Procesando Endpoint: 'licences' ---
# 🔑 Verificando PRIMARY KEY en la tabla 'licences'...
# ⚠️  No se pudo establecer la PRIMARY KEY: (1062, "Duplicate entry '87137' for key 'licences.PRIMARY'")
# 🗓️  Modo: Filtro por fechas. URL: https://cramer.buk.cl/api/v1/chile/employees/absences/licences?start_date_after=2025-09-01&start_date_before=2025-09-08
# 📡 Extrayendo datos...
#
# 🚀 Comenzando la obtención de datos desde: https://cramer.buk.cl/api/v1/chile/employees/absences/licences?start_date_after=2025-09-01&start_date_before=2025-09-08
# 📄 Obteniendo página 1...
# ⚠️  No se pudo establecer la PRIMARY KEY: (1062, "Duplicate entry '87137' for key 'licences.PRIMARY'")
# 🗓️  Modo: Filtro por fechas. URL: https://cramer.buk.cl/api/v1/chile/employees/absences/licences?start_date_after=2025-09-01&start_date_before=2025-09-08
# 📡 Extrayendo datos...
#
# 🚀 Comenzando la obtención de datos desde: https://cramer.buk.cl/api/v1/chile/employees/absences/licences?start_date_after=2025-09-01&start_date_before=2025-09-08
# 📄 Obteniendo página 1...
# ✅ Página 1: 25 datos obtenidos
# 📊 Total acumulado: 25 datos
# 📈 Páginas restantes: 136
# ✅ Página 1: 25 datos obtenidos
# 📊 Total acumulado: 25 datos
# 📈 Páginas restantes: 136
# 📄 Obteniendo página 2...
# 📄 Obteniendo página 2...
# ✅ Página 2: 25 datos obtenidos
# 📊 Total acumulado: 50 datos
# 📈 Páginas restantes: 135
# ✅ Página 2: 25 datos obtenidos
# 📊 Total acumulado: 50 datos
# 📈 Páginas restantes: 135
# 📄 Obteniendo página 3...
# 📄 Obteniendo página 3...
# ✅ Página 3: 25 datos obtenidos
# 📊 Total acumulado: 75 datos
# 📈 Páginas restantes: 134
# ✅ Página 3: 25 datos obtenidos
# 📊 Total acumulado: 75 datos
# 📈 Páginas restantes: 134
# 📄 Obteniendo página 4...
# 📄 Obteniendo página 4...
# ✅ Página 4: 25 datos obtenidos
# 📊 Total acumulado: 100 datos
# 📈 Páginas restantes: 133
# ✅ Página 4: 25 datos obtenidos
# 📊 Total acumulado: 100 datos
# 📈 Páginas restantes: 133
# 📄 Obteniendo página 5...
# 📄 Obteniendo página 5...
# ✅ Página 5: 25 datos obtenidos
# 📊 Total acumulado: 125 datos
# 📈 Páginas restantes: 132
# ✅ Página 5: 25 datos obtenidos
# 📊 Total acumulado: 125 datos
# 📈 Páginas restantes: 132
# 📄 Obteniendo página 6...
# 📄 Obteniendo página 6...
# ✅ Página 6: 25 datos obtenidos
# 📊 Total acumulado: 150 datos
# 📈 Páginas restantes: 131
# ✅ Página 6: 25 datos obtenidos
# 📊 Total acumulado: 150 datos
# 📈 Páginas restantes: 131
# 📄 Obteniendo página 7...
# 📄 Obteniendo página 7...
# ✅ Página 7: 25 datos obtenidos
# 📊 Total acumulado: 175 datos
# 📈 Páginas restantes: 130
# ✅ Página 7: 25 datos obtenidos
# 📊 Total acumulado: 175 datos
# 📈 Páginas restantes: 130
# 📄 Obteniendo página 8...
# 📄 Obteniendo página 8...
# ✅ Página 8: 25 datos obtenidos
# 📊 Total acumulado: 3200 datos
# 📈 Páginas restantes: 9
# 📄 Obteniendo página 129...
# 📄 Obteniendo página 129...
# ✅ Página 129: 25 datos obtenidos
# 📊 Total acumulado: 3225 datos
# 📈 Páginas restantes: 8
# ✅ Página 129: 25 datos obtenidos
# 📊 Total acumulado: 3225 datos
# 📈 Páginas restantes: 8
# 📄 Obteniendo página 130...
# 📄 Obteniendo página 130...
# ✅ Página 130: 25 datos obtenidos
# 📊 Total acumulado: 3250 datos
# 📈 Páginas restantes: 7
# ✅ Página 130: 25 datos obtenidos
# 📊 Total acumulado: 3250 datos
# 📈 Páginas restantes: 7
# 📄 Obteniendo página 131...
# 📄 Obteniendo página 131...
# ✅ Página 131: 25 datos obtenidos
# 📊 Total acumulado: 3275 datos
# 📈 Páginas restantes: 6
# ✅ Página 131: 25 datos obtenidos
# 📊 Total acumulado: 3275 datos
# 📈 Páginas restantes: 6
# 📄 Obteniendo página 132...
# 📄 Obteniendo página 132...
# ✅ Página 132: 25 datos obtenidos
# 📊 Total acumulado: 3300 datos
# 📈 Páginas restantes: 5
# ✅ Página 132: 25 datos obtenidos
# 📊 Total acumulado: 3300 datos
# 📈 Páginas restantes: 5
# 📄 Obteniendo página 133...
# 📄 Obteniendo página 133...
# ✅ Página 133: 25 datos obtenidos
# 📊 Total acumulado: 3325 datos
# 📈 Páginas restantes: 4
# ✅ Página 133: 25 datos obtenidos
# 📊 Total acumulado: 3325 datos
# 📈 Páginas restantes: 4
# 📄 Obteniendo página 134...
# 📄 Obteniendo página 134...
# ✅ Página 134: 25 datos obtenidos
# 📊 Total acumulado: 3350 datos
# 📈 Páginas restantes: 3
# ✅ Página 134: 25 datos obtenidos
# 📊 Total acumulado: 3350 datos
# 📈 Páginas restantes: 3
# 📄 Obteniendo página 135...
# 📄 Obteniendo página 135...
# ✅ Página 135: 25 datos obtenidos
# 📊 Total acumulado: 3375 datos
# 📈 Páginas restantes: 2
# ✅ Página 135: 25 datos obtenidos
# 📊 Total acumulado: 3375 datos
# 📈 Páginas restantes: 2
# 📄 Obteniendo página 136...
# 📄 Obteniendo página 136...
# ✅ Página 136: 25 datos obtenidos
# 📊 Total acumulado: 3400 datos
# 📈 Páginas restantes: 1
# ✅ Página 136: 25 datos obtenidos
# 📊 Total acumulado: 3400 datos
# 📈 Páginas restantes: 1
# 📄 Obteniendo página 137...
# 📄 Obteniendo página 137...
# ✅ Página 137: 22 datos obtenidos
# 📊 Total acumulado: 3422 datos
# 📈 Páginas restantes: 0
# ✅ Página 137: 22 datos obtenidos
# 📊 Total acumulado: 3422 datos
# 📈 Páginas restantes: 0
# 🎉 ¡Paginación completada! Total de datos obtenidos: 3422
# 📊 3422 registros encontrados. Actualizando tabla 'licences' en MySQL...
# 🚀 Insertando o actualizando registros en la tabla 'licences'...
# 🎉 ¡Paginación completada! Total de datos obtenidos: 3422
# 📊 3422 registros encontrados. Actualizando tabla 'licences' en MySQL...
# 🚀 Insertando o actualizando registros en la tabla 'licences'...
# ✅ 3422 registros insertados o actualizados en 'licences'.
#
# 🔄 --- Procesando Endpoint: 'permissions' ---
# 🔑 Verificando PRIMARY KEY en la tabla 'permissions'...
# ⚠️  No se pudo establecer la PRIMARY KEY: (1062, "Duplicate entry '85323' for key 'permissions.PRIMARY'")
# 🗓️  Modo: Filtro por fechas. URL: https://cramer.buk.cl/api/v1/chile/employees/absences/permissions?start_date_after=2025-09-01&start_date_before=2025-09-08
# 📡 Extrayendo datos...
#
# 🚀 Comenzando la obtención de datos desde: https://cramer.buk.cl/api/v1/chile/employees/absences/permissions?start_date_after=2025-09-01&start_date_before=2025-09-08
# 📄 Obteniendo página 1...
# ✅ 3422 registros insertados o actualizados en 'licences'.
#
# 🔄 --- Procesando Endpoint: 'permissions' ---
# 🔑 Verificando PRIMARY KEY en la tabla 'permissions'...
# ⚠️  No se pudo establecer la PRIMARY KEY: (1062, "Duplicate entry '85323' for key 'permissions.PRIMARY'")
# 🗓️  Modo: Filtro por fechas. URL: https://cramer.buk.cl/api/v1/chile/employees/absences/permissions?start_date_after=2025-09-01&start_date_before=2025-09-08
# 📡 Extrayendo datos...
#
# 🚀 Comenzando la obtención de datos desde: https://cramer.buk.cl/api/v1/chile/employees/absences/permissions?start_date_after=2025-09-01&start_date_before=2025-09-08
# 📄 Obteniendo página 1...
# ✅ Página 1: 25 datos obtenidos
# 📊 Total acumulado: 25 datos
# 📈 Páginas restantes: 25
# ✅ Página 1: 25 datos obtenidos
# 📊 Total acumulado: 25 datos
# 📈 Páginas restantes: 25
# 📄 Obteniendo página 2...
# 📄 Obteniendo página 2...
# ✅ Página 2: 25 datos obtenidos
# 📊 Total acumulado: 50 datos
# 📈 Páginas restantes: 24
# ✅ Página 2: 25 datos obtenidos
# 📊 Total acumulado: 50 datos
# 📈 Páginas restantes: 24
# 📄 Obteniendo página 3...
# 📄 Obteniendo página 3...
# ✅ Página 3: 25 datos obtenidos
# 📊 Total acumulado: 75 datos
# 📈 Páginas restantes: 23
# ✅ Página 3: 25 datos obtenidos
# 📊 Total acumulado: 75 datos
# 📈 Páginas restantes: 23
# 📄 Obteniendo página 4...
# 📄 Obteniendo página 4...
# ✅ Página 4: 25 datos obtenidos
# 📊 Total acumulado: 100 datos
# 📈 Páginas restantes: 22
# ✅ Página 4: 25 datos obtenidos
# 📊 Total acumulado: 100 datos
# 📈 Páginas restantes: 22
# 📄 Obteniendo página 5...
# 📄 Obteniendo página 5...
# ✅ Página 5: 25 datos obtenidos
# 📊 Total acumulado: 125 datos
# 📈 Páginas restantes: 21
# ✅ Página 5: 25 datos obtenidos
# 📊 Total acumulado: 125 datos
# 📈 Páginas restantes: 21
# 📄 Obteniendo página 6...
# 📄 Obteniendo página 6...
# ✅ Página 6: 25 datos obtenidos
# 📊 Total acumulado: 150 datos
# 📈 Páginas restantes: 20
# ✅ Página 6: 25 datos obtenidos
# 📊 Total acumulado: 150 datos
# 📈 Páginas restantes: 20
# 📄 Obteniendo página 7...
# 📄 Obteniendo página 7...
# ✅ Página 7: 25 datos obtenidos
# 📊 Total acumulado: 175 datos
# 📈 Páginas restantes: 19
# ✅ Página 7: 25 datos obtenidos
# 📊 Total acumulado: 175 datos
# 📈 Páginas restantes: 19
# 📄 Obteniendo página 8...
# 📄 Obteniendo página 8...
# ✅ Página 8: 25 datos obtenidos
# 📈 Páginas restantes: 7
# ✅ Página 19: 25 datos obtenidos
# 📊 Total acumulado: 475 datos
# 📈 Páginas restantes: 7
# 📄 Obteniendo página 20...
# 📄 Obteniendo página 20...
# ✅ Página 20: 25 datos obtenidos
# 📊 Total acumulado: 500 datos
# 📈 Páginas restantes: 6
# ✅ Página 20: 25 datos obtenidos
# 📊 Total acumulado: 500 datos
# 📈 Páginas restantes: 6
# 📄 Obteniendo página 21...
# 📄 Obteniendo página 21...
# ✅ Página 21: 25 datos obtenidos
# 📊 Total acumulado: 525 datos
# 📈 Páginas restantes: 5
# ✅ Página 21: 25 datos obtenidos
# 📊 Total acumulado: 525 datos
# 📈 Páginas restantes: 5
# 📄 Obteniendo página 22...
# 📄 Obteniendo página 22...
# ✅ Página 22: 25 datos obtenidos
# 📊 Total acumulado: 550 datos
# 📈 Páginas restantes: 4
# ✅ Página 22: 25 datos obtenidos
# 📊 Total acumulado: 550 datos
# 📈 Páginas restantes: 4
# 📄 Obteniendo página 23...
# 📄 Obteniendo página 23...
# ✅ Página 23: 25 datos obtenidos
# 📊 Total acumulado: 575 datos
# 📈 Páginas restantes: 3
# ✅ Página 23: 25 datos obtenidos
# 📊 Total acumulado: 575 datos
# 📈 Páginas restantes: 3
# 📄 Obteniendo página 24...
# 📄 Obteniendo página 24...
# ✅ Página 24: 25 datos obtenidos
# 📊 Total acumulado: 600 datos
# 📈 Páginas restantes: 2
# ✅ Página 24: 25 datos obtenidos
# 📊 Total acumulado: 600 datos
# 📈 Páginas restantes: 2
# 📄 Obteniendo página 25...
# 📄 Obteniendo página 25...
# ✅ Página 25: 25 datos obtenidos
# 📊 Total acumulado: 625 datos
# 📈 Páginas restantes: 1
# ✅ Página 25: 25 datos obtenidos
# 📊 Total acumulado: 625 datos
# 📈 Páginas restantes: 1
# 📄 Obteniendo página 26...
# 📄 Obteniendo página 26...
# ✅ Página 26: 15 datos obtenidos
# 📊 Total acumulado: 640 datos
# 📈 Páginas restantes: 0
# ✅ Página 26: 15 datos obtenidos
# 📊 Total acumulado: 640 datos
# 📈 Páginas restantes: 0
# 🎉 ¡Paginación completada! Total de datos obtenidos: 640
# 📊 640 registros encontrados. Actualizando tabla 'permissions' en MySQL...
# 🚀 Insertando o actualizando registros en la tabla 'permissions'...
# ✅ 640 registros insertados o actualizados en 'permissions'.
#
# 🎉 FASE 1 COMPLETADA: Tablas individuales actualizadas.
# 🎉 ¡Paginación completada! Total de datos obtenidos: 640
# 📊 640 registros encontrados. Actualizando tabla 'permissions' en MySQL...
# 🚀 Insertando o actualizando registros en la tabla 'permissions'...
# ✅ 640 registros insertados o actualizados en 'permissions'.
#
# 🎉 FASE 1 COMPLETADA: Tablas individuales actualizadas.

# %%
# --- FASE 2: Actualización Incremental de la Tabla Consolidada ---
print("\n🚀 FASE 2: Sincronizando la tabla 'consolidado_incidencias'...")

# Crear la tabla consolidada si no existe, con su propia clave primaria compuesta.
sql_create_consolidado = """
CREATE TABLE IF NOT EXISTS consolidado_incidencias (
    id INT, start_date VARCHAR(255), end_date VARCHAR(255), days_count VARCHAR(255),
    workday_stage VARCHAR(255), application_date VARCHAR(255), application_end_date VARCHAR(255),
    employee_id VARCHAR(255), status VARCHAR(255), created_at VARCHAR(255),
    tabla_origen VARCHAR(50), PRIMARY KEY (id, tabla_origen)
);
"""
cursor.execute(sql_create_consolidado)

# Sincronizar los datos desde las tablas individuales (ahora sin duplicados)
sql_sync_consolidado = """
INSERT INTO consolidado_incidencias (id, start_date, end_date, days_count, workday_stage, application_date, application_end_date, employee_id, status, created_at, tabla_origen)
(
    SELECT id, start_date, end_date, days_count, workday_stage, application_date, application_end_date, employee_id, status, created_at, 'permissions' AS tabla_origen FROM permissions
    UNION ALL
    SELECT id, start_date, end_date, days_count, workday_stage, application_date, application_end_date, employee_id, status, created_at, 'absences' AS tabla_origen FROM absences
    UNION ALL
    SELECT id, start_date, end_date, days_count, workday_stage, application_date, application_end_date, employee_id, status, created_at, 'licences' AS tabla_origen FROM licences
) AS source
ON DUPLICATE KEY UPDATE
    start_date = source.start_date, end_date = source.end_date, days_count = source.days_count,
    workday_stage = source.workday_stage, application_date = source.application_date,
    application_end_date = source.application_end_date, employee_id = source.employee_id,
    status = source.status, created_at = source.created_at;
"""
cursor.execute(sql_sync_consolidado)
conexion.commit()

registros_afectados = cursor.rowcount
print(f"✅ FASE 2 COMPLETADA: Tabla 'consolidado_incidencias' sincronizada. {registros_afectados} registros insertados/actualizados.")

# --- Finalizar ---
cursor.close()
conexion.close()
print("\n✅ Proceso finalizado. Conexión a la base de datos cerrada.")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[8], line 45
#       1 sql_consolidar = """
#       2 CREATE TABLE consolidado_incidencias AS
#       3 SELECT
#    (...)
#      43 FROM licences;
#      44 """
# ---> 45 cursor.execute(sql_consolidar)
#      46 conexion.commit()
#      47 print("✅ Tabla consolidado_incidencias actualizada.")
#
# File c:\Users\bgacitua\AppData\Local\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\bgacitua\AppData\Local\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File c:\Users\bgacitua\AppData\Local\anaconda3\Lib\site-packages\pymysql\connections.py:575, in Connection.query(self, sql, unbuffered)
#     573     sql = sql.encode(self.encoding, "surrogateescape")
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File c:\Users\bgacitua\AppData\Local\anaconda3\Lib\site-packages\pymysql\connections.py:826, in Connection._read_query_result(self, unbuffered)
#     824     result.init_unbuffered_query()
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#     828 if result.server_status is not None:
#
# File c:\Users\bgacitua\AppData\Local\anaconda3\Lib\site-packages\pymysql\connections.py:1203, in MySQLResult.read(self)
#    1201 def read(self):
#    1202     try:
# -> 1203         first_packet = self.connection._read_packet()
#    1205         if first_packet.is_ok_packet():
#    1206             self._read_ok_packet(first_packet)
#
# File c:\Users\bgacitua\AppData\Local\anaconda3\Lib\site-packages\pymysql\connections.py:782, in Connection._read_packet(self, packet_type)
#     780     if self._result is not None and self._result.unbuffered_active is True:
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File c:\Users\bgacitua\AppData\Local\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\bgacitua\AppData\Local\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1050, "Table 'consolidado_incidencias' already exists")
